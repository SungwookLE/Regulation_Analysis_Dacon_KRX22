# %%
# BERTopic 모델 사용 - 이유 : LDA, NMF 보다 더 높은 정확성

# %%
# 패키지 설치
# !pip install bertopic
# !pip install bertopic[visualization]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 76 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 88 kB 7.2 MB/s
# ...
#      |████████████████████████████████| 85 kB 4.8 MB/s
# ...
#      |████████████████████████████████| 5.2 MB 53.1 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 4.4 MB 58.3 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 64.7 MB/s
# ...
#      |████████████████████████████████| 101 kB 12.6 MB/s
# ...
#      |████████████████████████████████| 636 kB 51.2 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 52.5 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 54.9 MB/s
# ...
#   Created wheel for hdbscan: filename=hdbscan-0.8.28-cp37-cp37m-linux_x86_64.whl size=2342182 sha256=9d52efbd9469ed0e69e9ad8ebcc9c919837adf6b9cba7666fd7a698e01f63b86
# ...

# %%
# Mecab 설치
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# %cd Mecab-ko-for-Google-Colab
# !bash install_mecab-ko_on_colab190912.sh
# Out:
# Cloning into 'Mecab-ko-for-Google-Colab'...
# remote: Enumerating objects: 115, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 115 (delta 11), reused 10 (delta 3), pack-reused 91
# Receiving objects: 100% (115/115), 1.27 MiB | 30.97 MiB/s, done.
# Resolving deltas: 100% (50/50), done.
# /content/Mecab-ko-for-Google-Colab
# Installing konlpy.....
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 19.4 MB 542 kB/s
# ...
#      |████████████████████████████████| 453 kB 56.9 MB/s
# ...
# Done
# Installing mecab-0.996-ko-0.9.2.tar.gz.....
# ...
# from https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# --2022-07-20 13:33:21--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# ...

# %%
# 예시 데이터 불러오기(한글)
# !wget https://raw.githubusercontent.com/lovit/soynlp/master/tutorials/2016-10-20.txt
# Out:
# --2022-07-20 13:37:05--  https://raw.githubusercontent.com/lovit/soynlp/master/tutorials/2016-10-20.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 43694449 (42M) [text/plain]
# Saving to: ‘2016-10-20.txt’
#
# 2016-10-20.txt      100%[===================>]  41.67M  --.-KB/s    in 0.1s
#
# 2022-07-20 13:37:08 (329 MB/s) - ‘2016-10-20.txt’ saved [43694449/43694449]

# %%
# 데이터 보기
# !head -n 5 2016-10-20.txt
# Out:
#
# 19  1990  52 1 22
# ...

# %%
docs = "2016-10-20.txt"

# %%
# 필요한 함수 불러오기
from tqdm import tqdm
from sklearn.feature_extraction.text import CountVectorizer
from konlpy.tag import Mecab
from bertopic import BERTopic

# %%
type(docs) # str 형태의 데이터 확인
# Out:
# str

# %%
docs
# Out:
# '2016-10-20.txt'

# %%
# 데이터 전처리
# 1. HTML 코드 제거
documents = [line.strip() for line in open(docs, encoding="utf-8").readlines()]
preprocessed_documents = []

# 빈 문자열이거나 숫자로만 이루어진 줄은 제외
for line in tqdm(documents):
  if line and not line.replace(' ', '').isdecimal():
    preprocessed_documents.append(line)
# Out:
# 100%|██████████| 30091/30091 [00:00<00:00, 161960.71it/s]

# %%
class CustomTokenizer:
    def __init__(self, tagger):
        self.tagger = tagger

    def __call__(self, sent):
        sent = sent[:1000000]
        word_tokens = self.tagger.morphs(sent)
        result = [word for word in word_tokens if len(word) > 1]
        return result

# %%
custom_tokenizer = CustomTokenizer(Mecab())
vectorizer = CountVectorizer(tokenizer=custom_tokenizer, max_features=3000)

# %%
# model 선언
model = BERTopic(embedding_model="sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens", \
                 vectorizer_model=vectorizer,
                 nr_topics="auto",# 161 : 데이터셋의 업종 수 -> (수동 토픽 축소 사용)
                 calculate_probabilities=True)

# %%
pics, probs = model.fit_transform(preprocessed_documents) # 데이터 넣어주기
# Out:
# Downloading:   0%|          | 0.00/574 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.06k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/731 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/150 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/527 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/numba/np/ufunc/parallel.py:363: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   warnings.warn(problem)

# %%
# 상대적 빈도로 생성된 토픽
# -1번 토픽은 이상치로 분류된 것으로 제외 처리
model.get_topic_freq().head()
# Out:
#    Topic  Count
# 0     -1  10897
# 1      0    676
# 2      1    495
# 3      2    433
# 4      3    322

# %%
# 0번 토픽이 할당된 단어
# 연습데이터 결과 괜찮은듯(정치 분야)
model.get_topic(0)
# Out:
# [('재단', 0.010634706968638911),
#  ('의혹', 0.009536140149424164),
#  ('국정', 0.009243080967386137),
#  ('대통령', 0.008934541297387976),
#  ('원장', 0.008916107957636386),
#  ('수석', 0.008541673954600319),
#  ('회고록', 0.007850917027372064),
#  ('누리', 0.007675135352232213),
#  ('의원', 0.007496294454602191),
#  ('청와대', 0.007417646150327353)]

# %%
# TF-IDF 표현(2D) : 상호작용형 Plotly 모형
model.visualize_topics()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# 확률 시각화
model.visualize_distribution(probs[0])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 50번째 토픽까지 키워드 보기
for i in range(0, 20):
  print(i,'번째 토픽 :', model.get_topic(i))
# Out:
# 0 번째 토픽 : [('재단', 0.010634706968638911), ('의혹', 0.009536140149424164), ('국정', 0.009243080967386137), ('대통령', 0.008934541297387976), ('원장', 0.008916107957636386), ('수석', 0.008541673954600319), ('회고록', 0.007850917027372064), ('누리', 0.007675135352232213), ('의원', 0.007496294454602191), ('청와대', 0.007417646150327353)]
# 1 번째 토픽 : [('트럼프', 0.03320577872402244), ('클린턴', 0.028479658251915303), ('후보', 0.02346086306673134), ('토론', 0.023103971483544615), ('대선', 0.022442657325024044), ('힐러리', 0.0188007842272155), ('공화', 0.016249388694986707), ('도널드', 0.01488589767059073), ('라스베이거스', 0.01319476118022054), ('선거', 0.01305515208118577)]
# 2 번째 토픽 : [('한대', 0.028980326376968485), ('미샤', 0.02065233968098455), ('일리', 0.020516462716124773), ('프리즘', 0.02051555294870502), ('역삼동', 0.019347731226466023), ('이탈', 0.01908455120743898), ('방인권', 0.013977766835903405), ('투데이', 0.01348344560709085), ('시리즈', 0.012922573598860242), ('머니', 0.01241601638786278)]
# ...
